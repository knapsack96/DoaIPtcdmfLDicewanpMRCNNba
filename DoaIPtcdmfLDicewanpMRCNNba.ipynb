# %%
#installazione python 3.8
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# --2023-11-20 08:54:07--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   161MB/s    in 0.5s
#
# 2023-11-20 08:54:07 (161 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
# ...

# %%
# !pip install PyQt5==5.12.2
# !pip install PyQtWebEngine==5.12
# Out:
# ...
#      |████████████████████████████████| 61.5 MB 67 kB/s
# ...
#   Attempting uninstall: PyQt5
#     Found existing installation: PyQt5 5.15.10
#     Uninstalling PyQt5-5.15.10:
#       Successfully uninstalled PyQt5-5.15.10
# ...
#      |████████████████████████████████| 61.0 MB 18 kB/s
# ...

# %%
# !pip install git+https://github.com/knapsack96/PixelLib.git
# Out:
# ...
#   Cloning https://github.com/knapsack96/PixelLib.git to /tmp/pip-req-build-ozkaedz7
#   Running command git clone -q https://github.com/knapsack96/PixelLib.git /tmp/pip-req-build-ozkaedz7
# ...
#      |████████████████████████████████| 3.5 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 13.9 MB 58.2 MB/s
# ...
#      |████████████████████████████████| 61.7 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 9.2 MB 63.5 MB/s
# ...
#      |████████████████████████████████| 948 kB 71.1 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 70.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.5 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 79 kB 9.7 MB/s
# ...
#      |████████████████████████████████| 840 kB 65.2 MB/s
# ...
#      |████████████████████████████████| 154 kB 71.4 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 60.4 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 62.6 MB/s
# ...

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==2.4.0
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# ...
#      |████████████████████████████████| 394.8 MB 40 kB/s
# ...
#      |████████████████████████████████| 65 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 75.0 MB/s
# ...
#      |████████████████████████████████| 14.9 MB 64.8 MB/s
# ...
#      |████████████████████████████████| 57 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 65.9 MB/s
# ...
#      |████████████████████████████████| 462 kB 76.1 MB/s
# ...
#      |████████████████████████████████| 294 kB 77.6 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 73.4 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 65 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 132 kB 81.3 MB/s
# ...
#      |████████████████████████████████| 102 kB 14.4 MB/s
# ...
#      |████████████████████████████████| 226 kB 80.5 MB/s
# ...
#      |████████████████████████████████| 151 kB 76.7 MB/s
# ...

# %%
# !pip3 install imgaug==0.2.5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.7/562.7 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for imgaug: filename=imgaug-0.2.5-py3-none-any.whl size=561420 sha256=d4d6ec0ef68be5cd36124d4f14dd6db8182636447398f39a6167a9904f5b7c6f
#   Stored in directory: /root/.cache/pip/wheels/0b/da/38/c07f5c84a267780ad9425f219f7f0a76a65bed6a75d0626c78
# Successfully built imgaug
# ...
#   Attempting uninstall: imgaug
#     Found existing installation: imgaug 0.4.0
#     Uninstalling imgaug-0.4.0:
#       Successfully uninstalled imgaug-0.4.0
# ...

# %%
#questo è il blocco che conta per caricare i dati con georeferenziazione
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !ln -s /content/drive/MyDrive/ /mydrive
# !mkdir /content/dataset
# !mkdir /content/dataset/test
# !mkdir /content/dataset/train
# !cp /mydrive/Mask_RCNN_DATASET_EQUO/train.json /content/dataset
# !cp /mydrive/Mask_RCNN_DATASET_EQUO/test.json /content/dataset
# !cp /mydrive/Mask_RCNN_DATASET_EQUO/qgis.json /content/dataset
# !cp /mydrive/Mask_RCNN_DATASET_EQUO/*.tif /content/dataset/train
# !cp /mydrive/Mask_RCNN_DATASET_EQUO/*.tif /content/dataset/test
# !mkdir /content/no_geo
# !cp /mydrive/Tiles_NO_JSON/*.tif /content/no_geo
# Out:
# Mounted at /content/drive
# ln: failed to create symbolic link '/mydrive/MyDrive': File exists
# mkdir: cannot create directory ‘/content/dataset’: File exists
# mkdir: cannot create directory ‘/content/dataset/test’: File exists
# mkdir: cannot create directory ‘/content/dataset/train’: File exists
# mkdir: cannot create directory ‘/content/no_geo’: File exists

# %%
# Importazione del modello preaddestrato COCO
# !cp /mydrive/mask_rcnn_coco.h5 /content/mask_rcnn_coco.h5

# %%
# !pip install numpy==1.23.4
# Out:
# ...
#      |████████████████████████████████| 17.1 MB 8.1 MB/s
# ERROR: tensorflow 2.4.0 has requirement numpy~=1.19.2, but you'll have numpy 1.23.4 which is incompatible.
# ERROR: tensorboard 2.14.0 has requirement grpcio>=1.48.2, but you'll have grpcio 1.32.0 which is incompatible.
# ERROR: sahi 0.11.15 has requirement opencv-python<=4.8, but you'll have opencv-python 4.8.1.78 which is incompatible.
# ERROR: sahi 0.11.15 has requirement tqdm>=4.48.2, but you'll have tqdm 4.42.1 which is incompatible.
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ...

# %%
# !pip install protobuf==3.20.*
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 6.9 MB/s
# ERROR: tensorflow 2.4.0 has requirement numpy~=1.19.2, but you'll have numpy 1.23.4 which is incompatible.
# ERROR: tensorboard 2.14.0 has requirement grpcio>=1.48.2, but you'll have grpcio 1.32.0 which is incompatible.
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.1
#     Uninstalling protobuf-4.25.1:
#       Successfully uninstalled protobuf-4.25.1
# ...

# %%
# !pip install -U scikit-image==0.16.2
# Out:
# ...
#      |████████████████████████████████| 26.5 MB 4.5 MB/s
# ...
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.21.0
#     Uninstalling scikit-image-0.21.0:
#       Successfully uninstalled scikit-image-0.21.0
# ...

# %%
# !pip install imagecodecs
# Out:
# ...
#      |████████████████████████████████| 36.3 MB 84 kB/s
# ...

# %%
# Blocco per il TRAINING
# %cd /content
# !echo 'import pixellib' > train.py
# !echo 'from pixellib.custom_train import instance_custom_training' >> train.py
# !echo 'train_maskrcnn = instance_custom_training()' >> train.py
# !echo 'train_maskrcnn.modelConfig(network_backbone = "resnet101", num_classes= 3, class_names =["BG","Bottles","Worked wood","Nets"], batch_size = 1)' >> train.py
# !echo 'train_maskrcnn.load_pretrained_model("/content/mask_rcnn_coco.h5")' >> train.py
# !echo 'train_maskrcnn.load_dataset("dataset")' >> train.py
# !echo 'train_maskrcnn.train_model(num_epochs = 1, augmentation=False, path_trained_models = "mask_rcnn_models")' >> train.py
# Out:
# /content

# %%
# %cd /content
# !python train.py
# Out:
# /content
# 2023-09-15 13:35:25.019664: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using resnet101 as network backbone For Mask R-CNN model
# 2023-09-15 13:35:33.152255: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-09-15 13:35:33.153927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-09-15 13:35:33.183542: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-09-15 13:35:33.183789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
#import dei pesi
# !mkdir /content/mask_rcnn_models
# !cp /content/drive/MyDrive/pesi/mask_rcnn_model.001-1.915219.h5 mask_rcnn_models
#inversa: !cp /content/drive/MyDrive/pesi mask_rcnn_models

# %%
# Blocco per il TEST, place your own model here
# %cd /content
# !echo 'import pixellib' > test.py
# !echo 'from pixellib.custom_train import instance_custom_training' >> test.py
# !echo 'train_maskrcnn = instance_custom_training()' >> test.py
# !echo 'train_maskrcnn.modelConfig(network_backbone = "resnet101", num_classes= 3, batch_size = 1)' >> test.py
# !echo 'train_maskrcnn.load_dataset("dataset")' >> test.py
# !echo 'x = train_maskrcnn.evaluate_model("/content/mask_rcnn_models/mask_rcnn_model.001-1.915219.h5",iou_threshold=0.1)' >> test.py
# !echo 'print(x)'
# !echo 'train_maskrcnn.evaluate_model_qgis("dataset",iou_threshold=0.1)' >> test.py
# Out:
# /content
# print(x)

# %%
# %cd /content
# !python test.py
# Out:
# /content
# 2023-11-20 09:10:05.920562: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using resnet101 as network backbone For Mask R-CNN model
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 11/20/2023 09:10:17 - WARNING - tensorflow -   From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2023-11-20 09:10:17.207582: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...

# %%
# Creazione cartella risultati
# !mkdir /content/risultati

# %%
#in place of the model named here, you can load your own model
# %cd /content
# !echo 'import pixellib' > show.py
# !echo 'from pixellib.instance import custom_segmentation' >> show.py
# !echo 'import os' >> show.py
# !echo 'segment_image = custom_segmentation()' >> show.py
# !echo 'class_names= ["BG","Bottles","Worked wood","Nets"]' >> show.py
# !echo 'segment_image.inferConfig(num_classes= 3, class_names=class_names)' >> show.py
# !echo 'segment_image.load_model("/content/mask_rcnn_models/mask_rcnn_model.001-1.915219.h5")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AJ_12.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AJ_12_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AJ_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AJ_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AK_11.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AK_11_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AK_12.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AK_12_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AK_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AK_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AK_14.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AK_14_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AL_11.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AL_11_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AL_12.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AL_12_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AL_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AL_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AL_14.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AL_14_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AM_10.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AM_10_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AM_11.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AM_11_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AM_12.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AM_12_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_AM_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_AM_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BF_33.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BF_33_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BF_34.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BF_34_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BG_31.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BG_31_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BG_32.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BG_32_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BG_33.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BG_33_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BG_34.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BG_34_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BG_35.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BG_35_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BH_30.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BH_30_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BH_31.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BH_31_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BH_32.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BH_32_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BH_33.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BH_33_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BH_34.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BH_34_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BI_31.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BI_31_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BI_32.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BI_32_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BI_33.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BI_33_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BJ_31.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BJ_31_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BJ_32.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BJ_32_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BJ_33.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BJ_33_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BN_42.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BN_42_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BO_41.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BO_41_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BO_42.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BO_42_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BO_43.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BO_43_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BO_42.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BO_42_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BQ_40.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BQ_40_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BP_40.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BP_40_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BP_41.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BP_41_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BP_42.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BP_42_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BP_43.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BP_43_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BP_44.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BP_44_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BQ_39.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BQ_39_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BQ_40.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BQ_40_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BQ_41.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BQ_41_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BQ_42.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BQ_42_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BQ_43.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BQ_43_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BR_40.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BR_40_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BR_41.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BR_41_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BR_42.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BR_42_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_25mag_10m_BS_41.tif", show_bboxes=True, output_image_name="/content/risultati/TG_25mag_10m_BS_41_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_B_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_B_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_B_07.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_B_07_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_C_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_C_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_C_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_C_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_C_07.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_C_07_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_D_04.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_D_04_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_D_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_D_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_D_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_D_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_D_07.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_D_07_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_E_04.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_E_04_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_E_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_E_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_E_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_E_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_F_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_F_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_F_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_F_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_H_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_H_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_H_08.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_H_08_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_I_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_I_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_I_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_I_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_I_07.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_I_07_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_I_08.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_I_08_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_J_04.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_J_04_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_J_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_J_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_J_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_J_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_J_07.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_J_07_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_K_03.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_K_03_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_K_04.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_K_04_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_K_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_K_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_K_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_K_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_K_07.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_K_07_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_L_03.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_L_03_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_L_04.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_L_04_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_L_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_L_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_L_06.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_L_06_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_M_05.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_M_05_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_O_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_O_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_O_14.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_O_14_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_O_15.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_O_15_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_O_16.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_O_16_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_P_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_P_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_P_14.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_P_14_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_P_15.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_P_15_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_P_16.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_P_16_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_Q_12.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_Q_12_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_Q_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_Q_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_Q_14.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_Q_14_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_Q_15.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_Q_15_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_R_12.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_R_12_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_R_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_R_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_R_14.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_R_14_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_R_15.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_R_15_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_S_13.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_S_13_masked.tif")' >> show.py
# !echo 'x = segment_image.segmentImage("/content/dataset/test/TG_preLitter_10m_S_14.tif", show_bboxes=True, output_image_name="/content/risultati/TG_preLitter_10m_S_14_masked.tif")' >> show.py
# Out:
# /content

# %%
# %cd /content
# !python show.py
# Out:
# /content
# 2023-11-20 09:54:34.003337: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2023-11-20 09:54:43.319783: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-11-20 09:54:43.320978: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-11-20 09:54:43.341841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# Creazione cartella di output di classificazione a 3 classi in MyDrive
# !mkdir /mydrive/Mask_RCNN_OUTPUT_GEOREF

# %%
# Spostamento della cartela risultati in quella di output precedentemente creata
# !cp -r /content/risultati /mydrive/Mask_RCNN_OUTPUT_GEOREF

# %%
# !pip install rasterio
# Out:
# ...
#      |████████████████████████████████| 20.7 MB 1.2 MB/s
# ...

# %%
# Blocco per la GEOREFERENZIAZIONE
#qui termina la fase di interesse, orientazione tile : verso su nord, verso giu sud, verso destra est, verso sinistra ovest
# %cd /content
#la prima coordinata del bb è il top, la seconda è il left, la terza è il bottom e la quarta è il right
# !echo 'import pixellib' > show.py
# !echo 'from pixellib.instance import custom_segmentation' >> show.py
# !echo 'import rasterio as rio' >> show.py
# !echo 'import os' >> show.py
# !echo 'segment_image = custom_segmentation()' >> show.py
# !echo 'class_names= ["BG","Bottles","Worked wood","Nets"]' >> show.py
# !echo 'segment_image.inferConfig(num_classes= 3, class_names=class_names)' >> show.py
# !echo 'segment_image.load_model("/content/mask_rcnn_models/mask_rcnn_model.001-1.915219.h5")' >> show.py
# !echo 'id = 0' >> show.py
# !echo 'for i in os.listdir("/content/no_geo/"):' >> show.py
# !echo ' with rio.open("/content/no_geo/"+i) as dem_src:' >> show.py
# !echo '  lidar_dem_im = dem_src.read(1, masked=True)' >> show.py
# !echo '  lidar_dem_meta = dem_src.profile' >> show.py
# !echo ' x = segment_image.segmentImage("/content/no_geo/"+i, show_bboxes=True, output_image_name="/content/risultati/"+i[:len(i)-3]+"jpg")' >> show.py
# !echo ' classi = x[0]["class_ids"]' >> show.py
# !echo ' scores = x[0]["scores"]' >> show.py
# !echo ' le_x = [lidar_dem_meta["transform"][2]+(((y[1]+y[3])/2)*lidar_dem_meta["transform"][0]) for y in x[0]["rois"]]' >> show.py
# !echo ' le_y = [lidar_dem_meta["transform"][5]-lidar_dem_meta["transform"][0]*((y[0]+y[2])/2) for y in x[0]["rois"]]' >> show.py
# !echo ' with open("/content/risultati/"+i[:len(i)-3]+"txt","w") as f:' >> show.py
# !echo '   for k in range(len(classi)):' >> show.py
# !echo '     f.write(str(id)+","+class_names[classi[k]]+","+str(scores[k])+","+str(le_x[k])+","+str(le_y[k])+"\n")' >> show.py
# !echo '     id += 1' >> show.py
# !echo " #print([[lidar_dem_meta['transform'][2]-(((y[0]+y[2])/2)*lidar_dem_meta['transform'][0]),lidar_dem_meta['transform'][5]+(lidar_dem_meta['transform'][0]*((y[1]+y[3])/2))] for y in x[0]['rois']])" >> show.py
#per sapere quanti rifiuti, x = segment_....  len(x['class_ids'])
# Out:
# /content

# %%
# !python show.py
# Out:
# 2023-11-20 10:31:49.631078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /usr/local/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2023-11-20 10:31:57.140263: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-11-20 10:31:57.141478: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-11-20 10:31:57.167618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !mkdir /mydrive/risultati_metrosea #se già esiste non mandarlo in run

# %%
# !cp -r /content/risultati /mydrive/Mask_RCNN_OUTPUT_GEOREF
